# %%
import pandas as pd

Census21 = pd.read_csv (r"/Users/zack/Documents/LMSID/LMSID coding/Python/CSD/98-401-X2021003_eng_CSV/98-401-X2021003_English_CSV_data.csv",low_memory=False, encoding='latin-1')

Census21.drop(['TNR_SF', 'TNR_LF', 'DATA_QUALITY_FLAG', 'CHARACTERISTIC_NOTE', 'SYMBOL.1', 'C2_COUNT_MEN+', 'SYMBOL.2', 'C3_COUNT_WOMEN+', 'SYMBOL.3', 
               'C10_RATE_TOTAL', 'SYMBOL.4', 'C11_RATE_MEN+', 'SYMBOL.5', 'C12_RATE_WOMEN+', 'SYMBOL'], axis=1,  inplace = True)

Census21.rename(columns={'CENSUS_YEAR': 'Year', 'DGUID': 'ID', 'ALT_GEO_CODE':'Geography Code', 'GEO_LEVEL':'Geography Level', 'GEO_NAME': 'Geography Name', 
                         'CHARACTERISTIC_ID':'Characteristic ID', 'CHARACTERISTIC_NAME':'Characteristic Name', 'C1_COUNT_TOTAL':'Count'}, inplace = True)

Census21
# Out:
#          Year                ID  Geography Code           Geography Level  \
# 0        2021      2021S0503932             932  Census metropolitan area
# 1        2021      2021S0503932             932  Census metropolitan area
# 2        2021      2021S0503932             932  Census metropolitan area
# 3        2021      2021S0503932             932  Census metropolitan area
# 4        2021      2021S0503932             932  Census metropolitan area
# ...       ...               ...             ...                       ...
# 2291338  2021  2021A00054709012         4709012        Census subdivision
# 2291339  2021  2021A00054709012         4709012        Census subdivision
# 2291340  2021  2021A00054709012         4709012        Census subdivision
# 2291341  2021  2021A00054709012         4709012        Census subdivision
# 2291342  2021  2021A00054709012         4709012        Census subdivision
#
#                Geography Name  Characteristic ID  \
# ...

# %%
Indigenous21 = pd.read_csv(r"/Users/zack/Documents/LMSID/LMSID coding/Python/CSD/98100266-eng/98100266.csv",low_memory=False, encoding='latin-1')

# %%
for col in Indigenous21:
    print(col)
# Out:
# ï»¿REF_DATE
# GEO
# DGUID
# Registered or Treaty Indian status (3)
# Gender (3)
# Statistics (3)
# Age (20)
# Coordinate
# Indigenous identity (9):Total - Indigenous identity[1]
# Symbol
# Indigenous identity (9):Indigenous identity[2]
# Symbol.1
# Indigenous identity (9):Single Indigenous responses[3]
# Symbol.2
# Indigenous identity (9):First Nations (North American Indian)[4]
# Symbol.3
# Indigenous identity (9):MÃ©tis[5]
# Symbol.4
# Indigenous identity (9):InukÂ (Inuit)[6]
# Symbol.5
# Indigenous identity (9):Multiple Indigenous responses[7]
# Symbol.6
# Indigenous identity (9):Indigenous responses not included elsewhere[8]
# Symbol.7
# Indigenous identity (9):Non-Indigenous identity[9]
# Symbol.8

# %%
Indigenous21.drop(['Registered or Treaty Indian status (3)','Statistics (3)','Age (20)','Coordinate','Indigenous identity (9):Total - Indigenous identity[1]','Symbol','Indigenous identity (9):Indigenous identity[2]','Symbol.1','Indigenous identity (9):Single Indigenous responses[3]','Symbol.2','Indigenous identity (9):First Nations (North American Indian)[4]','Symbol.3','Indigenous identity (9):MÃ©tis[5]','Symbol.4','Indigenous identity (9):InukÂ (Inuit)[6]','Symbol.5',
                   'Indigenous identity (9):Multiple Indigenous responses[7]','Symbol.6','Indigenous identity (9):Indigenous responses not included elsewhere[8]','Symbol.7','Indigenous identity (9):Non-Indigenous identity[9]','Symbol.8'],axis=1)
